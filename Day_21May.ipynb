# %%
#Questions

l = [3,4,5,6,7, [23,456,67,8,78,78], [345,56,87,8,98,9], (234,6657,6), {"key1":"shay",234:[23,45,656]}]

# %%
#1. Try to reverse the list
l[::-1]
# Out:
# [{'key1': 'shay', 234: [23, 45, 656]},
#  (234, 6657, 6),
#  [345, 56, 87, 8, 98, 9],
#  [23, 456, 67, 8, 78, 78],
#  7,
#  6,
#  5,
#  4,
#  3]

# %%
#2 Try to access 234 out of this list
l[7][0]
# Out:
# 234

# %%
#3 Try to access 456 out of this list
l[5][1]
# Out:
# 456

# %%
#4 Try to extract only a list collection from list l
l[6]
# Out:
# [345, 56, 87, 8, 98, 9]

# %%
#5 Try to extract "shay"
l[8]['key1']
# Out:
# 'shay'

# %%
#6 Try to list all the key in dict element available in list
l[8].keys()
# Out:
# dict_keys(['key1', 234])

# %%
#7 Try to list all the value elements from dict available in list
l[8].values()
# Out:
# dict_values(['shay', [23, 45, 656]])
